# %% [markdown]
# https://www.wrl.unsw.edu.au/news/coastsat-how-to-estimate-beach-slopes-using-satellite-imagery
# https://www.wrl.unsw.edu.au/research/coastsat

# %% [markdown]
# # *CoastSat*: testing
#
#
# This example shows users how to extract time-series of shoreline change over the last 30+ years at their site of interest.
# There are five main steps:
# 1. Retrieval of the satellite images of the region of interest from Google Earth Engine
# 2. Shoreline extraction at sub-pixel resolution
# 3. Intersection of the shorelines with cross-shore transects
# 4. Tidal correction
# 5. Time-series post-processing
# 6. Validation against in situ surveys
#
# This software is described in details in the following publications:
# - Shoreline detection:                      https://doi.org/10.1016/j.envsoft.2019.104528
# - Accuracy assessment and applications:     https://doi.org/10.1016/j.coastaleng.2019.04.004
# - Beach slope estimation:                   https://doi.org/10.1029/2020GL088365
#
# ## Initial settings
#
# Refer to the **Installation** section of the README for instructions on how to install the Python packages necessary to run the software, including Google Earth Engine Python API. If that step has been completed correctly, the following packages should be imported without any problem.

# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
import pickle
import warnings
warnings.filterwarnings("ignore")
import matplotlib
matplotlib.use('Qt5Agg')
import matplotlib.pyplot as plt
from matplotlib import gridspec
plt.ion()
import pandas as pd
from datetime import datetime
from coastsat import SDS_download, SDS_preprocess, SDS_shoreline, SDS_tools, SDS_transects

# %% [markdown]
# ## 1. Retrieval of the images from GEE
#
# Define the region of interest (`polygon`), the date range (`dates`) and the satellite missions (`sat_list`) from which you wish to retrieve the satellite images. The images will be cropped on the Google Earth Engine server and only the region of interest will be downloaded as a .tif file. The files will stored in the directory defined in `filepath`.
#
# Make sure the area of your ROI is smaller than 100 km2 (if larger split it into smaller ROIs).
#
# The function `SDS_download.check_images_available(inputs)` will print the number of images available for your inputs. The Landsat images are divided in Tier 1 and Tier 2, only Tier 1 images can be used for time-series analysis.
#
# For Landsat, users can also choose between Collection 1 and Collection 2 with the `collection` variable. Note that from 1st Jan 2022 newly acquired Landsat images are only available in Collection 2, with Landsat 9 only available in Collection 2, so it's preferred that you use Collection 2.

# %%
#read a csv file with the coordinates of the sites
sitetable = pd.read_csv('G:/My Drive/MIT/satellite_AI/sat_data/areas_of_interest.csv')
sitetable
# Out:
#     ID         Atoll     Island Name    pt1lat    pt1long    pt2lat  \
# 0    0     Haa Alifu        Dhihdhoo  6.886873  73.102336  6.895814
# 1    1    Haa Dhaalu  Kulhudhuffushi  6.614142  73.061912  6.635586
# 2    2     Shaviyani        Funadhoo  6.154265  73.284247  6.170579
# 3    3     Shaviyani       Komandoo   6.051581  73.050525  6.056823
# 4    5     Lhaviyani       Hinnavaru  5.486331  73.407030  5.497300
# 5    6     Lhaviyani         Naifaru  5.439174  73.361303  5.450183
# 6    7           Baa      Eydhafushi  5.098853  73.063853  5.107673
# 7   10           Baa     Thulhaadhoo  5.016289  72.835511  5.027502
# 8   11         Kaafu      Thulusdhoo  4.366670  73.639003  4.379533
# 9   13         Kaafu           Huraa  4.327775  73.594801  4.339679
# 10  14         Kaafu      Hinmafushi  4.303612  73.563607  4.313739
# 11  15           MLE      Hulhumaale  4.169842  73.515465  4.244228
# 12  16           MLE           Maale  4.161777  73.493810  4.186330
# 13  18           MLE      Vilin'gili  4.164845  73.478492  4.180755
# 14  19         Kaafu      Gulhifalhu  4.170164  73.451767  4.193045
# 15  20         Kaafu      Thilafushi  4.175792  73.405359  4.196129
# 16  21         Kaafu        Maafushi  3.924934  73.476514  3.959443
# 1                Extension          NaN
# 2                Extension          NaN
# 3                Extension          NaN
# 4                Extension          NaN
# 5                Extension          NaN
# 6                Extension          NaN
# 7                Extension          NaN
# 8                Extension          NaN
# 9                Extension          NaN
# 10               Extension          NaN
# 11              New Island          NaN
# 12               Extension          NaN
# 13               Extension          NaN
# 14              New Island          NaN
# 15              New Island          NaN
# 16              New Island          NaN
# 17               Extension          NaN
# 18               Extension          NaN
# 19               Extension          NaN
# 20               Extension          NaN
# 21  Extension/Safer island          NaN
# 22               Extension          NaN
# 23               Extension          NaN
# 24               Extension          NaN
# 25               Extension          NaN
# 26               Extension          NaN
# 27               Extension          NaN
# 28               Extension          NaN
# 29               Extension          NaN

# %%
#functions to get the coordinates of a site from the csv file
def get_site_coordinates(sites, site_name):
    site = sites[sites['Island Name'] == site_name]
    polygon =  np.expand_dims(site[['pt1long','pt1lat','pt2long','pt2lat','pt3long','pt3lat','pt4long','pt4lat']].values[0].reshape(4,2), axis=0)
    date = site['Critical date'].values[0]
    return polygon,date

from datetime import timedelta   
def set_date_range(date_string, days_before, days_after):
    date = datetime.strptime(date_string, '%m/%d/%y')
    date_before = date - timedelta(days=days_before)
    date_after = date + timedelta(days=days_after)
    date_before = datetime.strftime(date_before, '%Y-%m-%d')
    date_after = datetime.strftime(date_after, '%Y-%m-%d')
    return [date_before, date_after]

# %%
#functions to check or download the images
def batch_download(sitetable, site_list, days_after, days_before):
    inputs_list = []
    for site in site_list:
        site_poly,site_date = get_site_coordinates(sitetable, site)
        date_range = set_date_range(site_date, days_before, days_after) 
        # it's recommended to convert the polygon to the smallest rectangle (sides parallel to coordinate axes)       
        polygon = SDS_tools.smallest_rectangle(site_poly)
        # date range
        dates = date_range
        # satellite missions ['L5','L7','L8','L9','S2']
        sat_list = ['S2']
        # choose Landsat collection 'C01' or 'C02'
        collection = 'C02'
        # name of the site
        sitename = site
        # directory where the data will be stored
        filepath = os.path.join(os.getcwd(), 'data')
        # put all the inputs into a dictionnary
        inputs = {'polygon': polygon, 'dates': dates, 'sat_list': sat_list, 'sitename': sitename, 'filepath':filepath,
         'landsat_collection': collection}

        inputs['include_T2'] = False# inputs['include_T2'] = True
        metadata = SDS_download.check_images_available(inputs);
        if(len(metadata[0]['S2']) > 0):
            metadata = SDS_download.retrieve_images(inputs)
        inputs_list.append(inputs)  
    return inputs_list

def batch_check(sitetable, site_list, days_after, days_before):
    inputs_list = []
    for site in site_list:
        site_poly,site_date = get_site_coordinates(sitetable, site)
        date_range = set_date_range(site_date, days_before, days_after) 
        # it's recommended to convert the polygon to the smallest rectangle (sides parallel to coordinate axes)       
        polygon = SDS_tools.smallest_rectangle(site_poly)
        # date range
        dates = date_range
        # satellite missions ['L5','L7','L8','L9','S2']
        sat_list = ['S2']
        # choose Landsat collection 'C01' or 'C02'
        collection = 'C02'
        # name of the site
        sitename = site
        # directory where the data will be stored
        filepath = os.path.join(os.getcwd(), 'data')
        # put all the inputs into a dictionnary
        inputs = {'polygon': polygon, 'dates': dates, 'sat_list': sat_list, 'sitename': sitename, 'filepath':filepath,
         'landsat_collection': collection}

        inputs['include_T2'] = False# inputs['include_T2'] = True
        metadata = SDS_download.check_images_available(inputs)
        inputs_list.append(inputs)  
    return inputs_list

# %%
site_names = sitetable['Island Name'].values
site_names
# Out:
# array(['Dhihdhoo', 'Kulhudhuffushi', 'Funadhoo', 'Komandoo ', 'Hinnavaru',
#        'Naifaru', 'Eydhafushi', 'Thulhaadhoo', 'Thulusdhoo', 'Huraa',
#        'Hinmafushi', 'Hulhumaale', 'Maale', "Vilin'gili", 'Gulhifalhu',
#        'Thilafushi', 'Maafushi', 'Nilandhoo', 'Meedhoo', 'Maduvvari',
#        'Muli', 'Vilufushi', 'Madifushi', 'Guraidhoo', "Vilin'gili",
#        'Dhaandhoo', 'Thinadhoo', 'Gahdhoo', 'Hithadhoo', 'Feydhoo'],
#       dtype=object)

# %%
site_names = ['Hinnavaru','Eydhafushi', 'Thulhaadhoo', 'Thulusdhoo', 'Huraa',
       'Hinmafushi', 'Hulhumaale', 'Maale', "Vilin'gili", 'Gulhifalhu','Thilafushi', 'Maafushi', 'Nilandhoo', 'Meedhoo', 'Maduvvari',
       'Muli', 'Vilufushi', 'Madifushi', 'Guraidhoo', "Vilin'gili", 'Dhaandhoo', 'Thinadhoo', 'Gahdhoo', 'Hithadhoo', 'Feydhoo']

# %%
site_names = site_names[0:1]

# %%
inputs_list = batch_check(sitetable, site_names, 365*3, 0)
# Out:
# Number of images available between 2014-06-01 and 2017-05-31:
# - In Landsat Tier 1 & Sentinel-2 Level-1C:
#      S2: 82 images
#   Total to download: 82 images

# %%
#inputs_list = batch_download(sitetable, site_names, 365*3, 0)

# %%
def remove_duplicates(folder):
    for root, dirs, files in os.walk(folder):
        for file in files:
            if "dup" in file:
                os.remove(os.path.join(root, file))
                print(f"removed {file}")

# %%
remove_duplicates('data/'+site_names[0])

# %%
# settings for the sand contour mapping
settings = { 
    # general parameters:
    'cloud_thresh': 0.2,        # threshold on maximum cloud cover
    'dist_clouds': 30,         # ditance around clouds where shoreline can't be mapped
    'output_epsg': 3857,        # epsg code of spatial reference system desired for the output
    # quality control:
    'check_detection': False,    # if True, shows each shoreline detection to the user for validation
    'adjust_detection': False,  # if True, allows user to adjust the postion of each shoreline by changing the threhold        
    'check_detection_sand_poly': False, # if True, uses sand polygon for detection and shows user for validation 
    'save_figure': False,               # if True, saves a figure showing the mapped shoreline for each image
    # add the inputs defined previously
    'inputs': inputs_list[0],
    # [ONLY FOR ADVANCED USERS] shoreline detection parameters:
    'min_beach_area': 3,        # minimum area (in metres^2) for an object to be labelled as a beach
    'buffer_size': 25,         # radius (in metres) of the buffer around sandy pixels considered in the shoreline detection
    'min_length_sl': 50,       # minimum length (in metres) of shoreline perimeter to be valid
    'cloud_mask_issue': True,  # switch this parameter to True if sand pixels are masked (in black) on many images
    'sand_color': 'bright',    # 'default', 'dark' (for grey/black sand beaches) or 'bright' (for white sand beaches)
    'pan_off': False,           # True to switch pansharpening off for Landsat 7/8/9 imagery
    's2cloudless_prob': 60,     # probability threshold to identify cloudy pixels in the s2cloudless mask
}
metadata = SDS_download.check_images_available(inputs_list[0])
metadata
#SDS_preprocess.save_jpg(metadata, settings)
# Out:
# Number of images available between 2014-06-01 and 2017-05-31:
# - In Landsat Tier 1 & Sentinel-2 Level-1C:
#      S2: 82 images
#   Total to download: 82 images
# ({'S2': [{'type': 'Image',
#     'bands': [{'id': 'B1',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B2',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B3',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B4',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B5',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B6',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B7',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B8',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B8A',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B9',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B10',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B11',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B12',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'QA10',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'QA20',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 4294967295},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'QA60',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]}],
#     'version': 1618033132689756,
#     'id': 'COPERNICUS/S2/20150816T053706_20150816T053706_T43NCG',
#     'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20150816T053706_000774_N02.04',
#      'SPACECRAFT_NAME': 'Sentinel-2A',
#      'FORMAT_CORRECTNESS_FLAG': 'FAILED',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 109.079193963,
#      'MEAN_SOLAR_AZIMUTH_ANGLE': 68.876292665,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[74.1843099620498, 6.332490644974854],
#        [74.18429858558207, 6.332491311593887],
#        [73.19199392865109, 6.3299841067665445],
#        [73.19195234083293, 6.329947348827454],
#        [73.19190643219358, 6.329916149514838],
#        [73.19190364166812, 6.329901373524899],
#        [73.19356120768515, 5.83359138533271],
#        [73.19508121757558, 5.337279754129667],
#        [73.19511803398527, 5.337238406612969],
#        [73.19514944944989, 5.337192839213478],
#        [73.19516430203193, 5.33719003028736],
#        [74.18573308994598, 5.339301736873909],
#        [74.1857747436159, 5.33933838163766],
#        [74.18582060743084, 5.339369507254613],
#        [74.18582338434115, 5.33938430980107],
#        [74.18513739665198, 5.835901078735923],
#        [74.18438932856907, 6.332401475985002],
#        [74.18435242224606, 6.332442930116093],
#        [74.1843210697814, 6.332488557848704],
#        [74.1843099620498, 6.332490644974854]]},
#      'SOLAR_IRRADIANCE_B12': 85.25,
#      'SOLAR_IRRADIANCE_B10': 367.15,
#      'SENSOR_QUALITY': 'PASSED',
#      'SOLAR_IRRADIANCE_B11': 245.59,
#      'GENERATION_TIME': 1439703426000,
#      'SOLAR_IRRADIANCE_B8A': 955.19,
#      'FORMAT_CORRECTNESS': 'FAILED',
#      'SENSOR_QUALITY_FLAG': 'PASSED',
#      'CLOUD_COVERAGE_ASSESSMENT': 94.2243,
#      'system:time_end': 1439703426000,
#      'system:time_start': 1439703426000,
#      'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_EPA__20160921T190944_S20150816T053706_N02.04',
#      'PROCESSING_BASELINE': '02.04',
#      'SENSING_ORBIT_NUMBER': 62,
#      'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#      'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#      'GENERAL_QUALITY': 'PASSED',
#      'GRANULE_ID': 'L1C_T43NCG_A000774_20150816T053706',
#      'REFLECTANCE_CONVERSION_CORRECTION': 0

#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[73.19508121757558, 5.337279754129667],
#        [73.19515133977856, 5.337189974811616],
#        [74.18573308994598, 5.339301736873909],
#        [74.18582338434115, 5.339371430976121],
#        [74.18497687265754, 5.945988960254964],
#        [74.18488129273537, 5.946839119373977],
#        [74.1842983168466, 5.947421035214357],
#        [74.17885141673503, 5.948775918667005],
#        [74.07175224661167, 5.975199290239986],
#        [73.90255899948986, 6.011790212211412],
#        [73.88737439100092, 6.015015635591507],
#        [73.6557993606247, 6.064055065401],
#        [73.63627392612159, 6.068166507181822],
#        [73.62813822923239, 6.069773938648332],
#        [73.2159335517519, 6.150492667605745],
#        [73.19423092786498, 6.154037959645018],
#        [73.19250684444319, 6.154032140074805],
#        [73.19384061806706, 5.745614072297224],
#        [73.19508121757558, 5.337279754129667]]},
#      'SOLAR_IRRADIANCE_B12': 85.25,
#      'SOLAR_IRRADIANCE_B10': 367.15,
#      'SENSOR_QUALITY': 'PASSED',
#      'SOLAR_IRRADIANCE_B11': 245.59,
#      'GENERATION_TIME': 1494999439000,
#      'SOLAR_IRRADIANCE_B8A': 955.19,
#      'FORMAT_CORRECTNESS': 'PASSED',
#      'PRODUCT_URI': 'S2A_MSIL1C_20170517T053721_N0205_R062_T43NCG_20170517T053719.SAFE',
#      'SENSOR_QUALITY_FLAG': 'PASSED',
#      'CLOUD_COVERAGE_ASSESSMENT': 50.4644,
#      'system:time_end': 1494999439460,
#      'system:time_start': 1494999439460,
#      'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_MTI__20170517T091346_S20170517T053719_N02.05',
#      'PROCESSING_BASELINE': '02.05',
#      'SENSING_ORBIT_NUMBER': 62,
#      'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#      'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#      'GENERAL_QUALITY': 'PASSED',
#      'GRANULE_ID': 'L1C_T43NCG_A009926_20170517T053719',
#      'REFLECTANCE_CONVERSION_CORRECTION': 0.979429066982,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 119.38703691,
#      'DATATAKE_TYPE': 'INS-NOBS',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 115.118133474,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 115.917760709,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 115.26821343,
#      'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 116.989776746,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.03610984382,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 116.391525444,
#      'RADIOMETRIC_QUALITY': 'PASSED',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 120.646665083,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 118.102888667,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.73996192151,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 115.346948191,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.67285263056,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.56154009348,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 3.47526366071,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.11840794307,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 3.51882136898,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.87237537868,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.80714061468,
#      'MEAN_SOLAR_ZENITH_ANGLE': 24.5450737531,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.94613763585,
#      'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#      'MGRS_TILE': '43NCG',
#      'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#      'CLOUDY_PIXEL_PERCENTAGE': 50.4644,
#      'GENERAL_QUALITY_FLAG': 'PASSED',
#      'PRODUCT_ID': 'S2A_MSIL1C_20170517T053721_N0205_R062_T43NCG_20170517T053719',
#      'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_PDMC_20170516T120000_V20170517T030000_20170517T150000',
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.64492493233,
#      'SOLAR_IRRADIANCE_B9': 813.04,
#      'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.80089007415,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.97355959935,
#      'SOLAR_IRRADIANCE_B6': 1288.32,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 117.105704276,
#      'SOLAR_IRRADIANCE_B5': 1425.56,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 115.747980475,
#      'SOLAR_IRRADIANCE_B8': 1036.39,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 114.903588818,
#      'SOLAR_IRRADIANCE_B7': 1163.19,
#      'SOLAR_IRRADIANCE_B2': 1941.63,
#      'SOLAR_IRRADIANCE_B1': 1913.57,
#      'SOLAR_IRRADIANCE_B4': 1512.79,
#      'GEOMETRIC_QUALITY': 'PASSED',
#      'SOLAR_IRRADIANCE_B3': 1822.61,
#      'system:asset_size': 929279198,
#      'system:index': '20170517T053721_20170517T053719_T43NCG'}},
#    {'type': 'Image',
#     'bands': [{'id': 'B1',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B2',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B3',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B4',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B5',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B6',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B7',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B8',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'B8A',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B9',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B10',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]},
#      {'id': 'B11',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'B12',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'QA10',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [10980, 10980],
#       'crs': 'EPSG:32643',
#       'crs_transform': [10, 0, 300000, 0, -10, 700020]},
#      {'id': 'QA20',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 4294967295},
#       'dimensions': [5490, 5490],
#       'crs': 'EPSG:32643',
#       'crs_transform': [20, 0, 300000, 0, -20, 700020]},
#      {'id': 'QA60',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': 0,
#        'max': 65535},
#       'dimensions': [1830, 1830],
#       'crs': 'EPSG:32643',
#       'crs_transform': [60, 0, 300000, 0, -60, 700020]}],
#     'version': 1617881181161910.0,
#     'id': 'COPERNICUS/S2/20170527T053721_20170527T053719_T43NCG',
#     'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20170527T053721_010069_N02.05',
#      'SPACECRAFT_NAME': 'Sentinel-2A',
#      'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#      'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20170525T000000_V20170526T000000_20180525T000000',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 115.565802717,
#      'MEAN_SOLAR_AZIMUTH_ANGLE': 50.9575134128,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[74.18573308994598, 5.339301736873909],
#        [74.18582338434115, 5.339371430976121],
#        [74.18500025255602, 5.930068135885136],
#        [74.1849051205369, 5.931099334289577],
#        [74.1845955380346, 5.931408408484912],
#        [74.18294478093087, 5.931956699131518],
#        [74.0804566965535, 5.956761627925872],
#        [74.066899217308, 5.9599952830006035],
#        [73.99803186908723, 5.975070139128991],
#        [73.89120317604745, 5.998200327493361],
#        [73.65638033074, 6.0481394033789115],
#        [73.55604859619412, 6.0679586124843174],
#        [73.22683578225796, 6.132263965282026],
#        [73.21924219621974, 6.133685531373839],
#        [73.21056383096492, 6.135284286897695],
#        [73.19428511750203, 6.1381245322744],
#        [73.19256049439532, 6.1381186678053075],
#        [73.19386573257859, 5.737657166657759],
#        [73.19508148762262, 5.337189786743799],
#        [74.18573308994598, 5.339301736873909]]},
#      'SOLAR_IRRADIANCE_B12': 85.25,
#      'SOLAR_IRRADIANCE_B10': 367.15,
#      'SENSOR_QUALITY': 'PASSED',
#      'SOLAR_IRRADIANCE_B11': 245.59,
#      'GENERATION_TIME': 1495863439000,
#      'SOLAR_IRRADIANCE_B8A': 955.19,
#      'FORMAT_CORRECTNESS': 'PASSED',
#      'PRODUCT_URI': 'S2A_MSIL1C_20170527T053721_N0205_R062_T43NCG_20170527T053719.SAFE',
#      'SENSOR_QUALITY_FLAG': 'PASSED',
#      'CLOUD_COVERAGE_ASSESSMENT': 63.9502,
#      'system:time_end': 1495863439460,
#      'system:time_start': 1495863439460,
#      'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_SGS__20170527T104304_S20170527T053719_N02.05',
#      'PROCESSING_BASELINE': '02.05',
#      'SENSING_ORBIT_NUMBER': 62,
#      'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#      'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#      'GENERAL_QUALITY': 'PASSED',
#      'GRANULE_ID': 'L1C_T43NCG_A010069_20170527T053719',
#      'REFLECTANCE_CONVERSION_CORRECTION': 0.975404632831,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 119.624789391,
#      'DATATAKE_TYPE': 'INS-NOBS',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 115.051751929,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 116.193603589,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 115.815827329,
#      'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 117.21483607,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.02539554921,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 116.660181501,
#      'RADIOMETRIC_QUALITY': 'PASSED',
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 120.889497785,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 118.610478714,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.74391380686,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 115.3543975,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.68044664081,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.57563644681,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 3.48216196175,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.11346863317,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 3.52592973861,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.88244782802,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.81122265444,
#      'MEAN_SOLAR_ZENITH_ANGLE': 25.7438421142,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.94653911272,
#      'GRI_FILENAME': 'S2A_OPER_AUX_GRI065_PDMC_20130621T120000_S20130101T000000',
#      'MGRS_TILE': '43NCG',
#      'PRODUCTION_DEM_TYPE': 'S2__OPER_DEM_GLOBEF_PDMC_19800101T000000_S19800101T000000',
#      'CLOUDY_PIXEL_PERCENTAGE': 63.9502,
#      'GENERAL_QUALITY_FLAG': 'PASSED',
#      'PRODUCT_ID': 'S2A_MSIL1C_20170527T053721_N0205_R062_T43NCG_20170527T053719',
#      'ECMWF_DATA_REF': 'S2__OPER_AUX_ECMWFD_PDMC_20170526T120000_V20170526T210000_20170527T090000',
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.64890271353,
#      'SOLAR_IRRADIANCE_B9': 813.04,
#      'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.80169118123,
#      'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.97057530795,
#      'SOLAR_IRRADIANCE_B6': 1288.32,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 117.441028883,
#      'SOLAR_IRRADIANCE_B5': 1425.56,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 116.005338263,
#      'SOLAR_IRRADIANCE_B8': 1036.39,
#      'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 115.334950484,
#      'SOLAR_IRRADIANCE_B7': 1163.19,
#      'SOLAR_IRRADIANCE_B2': 1941.63,
#      'SOLAR_IRRADIANCE_B1': 1913.57,
#      'SOLAR_IRRADIANCE_B4': 1512.79,
#      'GEOMETRIC_QUALITY': 'PASSED',
#      'SOLAR_IRRADIANCE_B3': 1822.61,
#      'system:asset_size': 820506898,
#      'system:index': '20170527T053721_20170527T053719_T43NCG'}}]},
#  [])
